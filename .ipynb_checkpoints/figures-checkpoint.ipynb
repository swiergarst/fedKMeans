# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from common import *

# %% [markdown]
# # Synthetic, original

# %%
cent_orig = np.genfromtxt("results/cent_synth_orig.csv", delimiter = ",")
om_orig = np.genfromtxt("results/om_synth_orig.csv", delimiter = ",")
ds_orig = np.genfromtxt("results/ds_synth_orig.csv", delimiter = ",")
ds_untuned_orig = np.genfromtxt("results/ds_synth_orig_untuned.csv", delimiter = ",")
V2_beta01 = np.genfromtxt("results/V2_beta01.csv", delimiter = ",")
V2_beta1 = np.genfromtxt("results/V2_beta1.csv", delimiter = ",")
V2_beta10 = np.genfromtxt("results/V2_beta10.csv", delimiter = ",")

# %%
V2_toPlot = np.array([V2_beta01[-1,:], V2_beta1[-1,:], V2_beta10[-1,:]])

# %%
V2_toPlot.shape
# Out:
# (3, 200)

# %%
bp2 = plt.boxplot(om_orig, positions = [-0.5, 1.5, 3.5], widths = 0.2, patch_artist = True, boxprops=dict(facecolor="red"))
bp4 = plt.boxplot(V2_toPlot.T, positions = [-0.2, 1.8, 3.8], widths = 0.2, patch_artist = True, boxprops=dict(facecolor="green"))
bp1 = plt.boxplot(ds_orig, positions = [0.2, 2.2, 4.2], widths = 0.2, patch_artist = True, boxprops=dict(facecolor="blue"))
bp3 = plt.boxplot(cent_orig[:,0], positions = [6], widths = 0.2, patch_artist = True, boxprops=dict(facecolor="purple"))
bp5 = plt.boxplot(ds_untuned_orig, positions = [0.5, 2.5,4.5], widths = 0.2, patch_artist = True, boxprops=dict(facecolor="lightblue"))
#plt.ylim([0.7, 1])
plt.xticks([0, 2, 4, 6], [r"$\beta$ = 0.1",r"$\beta$ = 1",r"$\beta$ = 10", "central"])
plt.grid(True)
plt.legend([bp2['boxes'][0],bp4['boxes'][0], bp1['boxes'][0], bp5['boxes'][0] ], ["Original Method","Updated Method", "Dennis et. al.", "Dennis et. al., untuned"])
plt.title("ARI for different levels of heterogeneity")
#plt.savefig("synth_orig.eps",format = "eps")
# Out:
# Text(0.5, 1.0, 'ARI for different levels of heterogeneity')

# %%
V2_abl = np.load("results/abl_V2.npy")
central_abl = np.load("results/scores_central_abl.npy")

# %%
V2_abl.shape
#central_abl.shape
# Out:
# (10, 200, 3, 3, 6)

# %%
V2_abl[-1,:,beta_i, ppc_i, :].shape
# Out:
# (200, 6)

# %%
bp1
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f02fb725e50>,
#   <matplotlib.lines.Line2D at 0x7f02fb735dd0>,
#   <matplotlib.lines.Line2D at 0x7f02fb6c7610>,
#   <matplotlib.lines.Line2D at 0x7f02fb6c7a10>,
#   <matplotlib.lines.Line2D at 0x7f02fb6dc050>,
#   <matplotlib.lines.Line2D at 0x7f02fb6dc490>,
#   <matplotlib.lines.Line2D at 0x7f02fb6e8b50>,
#   <matplotlib.lines.Line2D at 0x7f02fb6e8f50>,
#   <matplotlib.lines.Line2D at 0x7f02fb6ff6d0>,
#   <matplotlib.lines.Line2D at 0x7f02fb6ffa90>,
#   <matplotlib.lines.Line2D at 0x7f02fb696190>,
#   <matplotlib.lines.Line2D at 0x7f02fb696590>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f02fb73c250>,
#   <matplotlib.lines.Line2D at 0x7f02fb73c690>,
#   <matplotlib.lines.Line2D at 0x7f02fb6c7e10>,
#   <matplotlib.lines.Line2D at 0x7f02fb6d2210>,
#   <matplotlib.lines.Line2D at 0x7f02fb6dc890>,
#   <matplotlib.lines.Line2D at 0x7f02fb6dccd0>,
#   <matplotlib.lines.Line2D at 0x7f02fb6f4390>,
#   <matplotlib.lines.Line2D at 0x7f02fb6f4790>,
#   <matplotlib.lines.Line2D at 0x7f02fb6ffe90>,
#   <matplotlib.lines.Line2D at 0x7f02fb68a290>,
#   <matplotlib.lines.Line2D at 0x7f02fb696990>,
#   <matplotlib.lines.Line2D at 0x7f02fb696d90>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x7f02fb725f50>,
#   <matplotlib.patches.PathPatch at 0x7f02fb6c7210>,
#   <matplotlib.patches.PathPatch at 0x7f02fb6d2c10>,
#   <matplotlib.patches.PathPatch at 0x7f02fb6e8750>,
#   <matplotlib.patches.PathPatch at 0x7f02fb6ff250>,
#   <matplotlib.patches.PathPatch at 0x7f02fb68ad50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f02fb73cad0>,
#   <matplotlib.lines.Line2D at 0x7f02fb6d2610>,
#   <matplotlib.lines.Line2D at 0x7f02fb6e8110>,
#   <matplotlib.lines.Line2D at 0x7f02fb6f4b90>,
#   <matplotlib.lines.Line2D at 0x7f02fb68a690>,
#   <matplotlib.lines.Line2D at 0x7f02fb6a31d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f02fb73cf50>,
#   <matplotlib.lines.Line2D at 0x7f02fb6d29d0>,
#   <matplotlib.lines.Line2D at 0x7f02fb6e8510>,
#   <matplotlib.lines.Line2D at 0x7f02fb6f4f90>,
#   <matplotlib.lines.Line2D at 0x7f02fb68aad0>,
#   <matplotlib.lines.Line2D at 0x7f02fb6a35d0>],
#  'means': []}

# %%
ppc_i = 2
noise_i = 0
beta_i = 0
bp1 = plt.boxplot(V2_abl[-1,:,beta_i, ppc_i, :], positions = [-0.2,1.8,3.8,5.8,7.8, 9.8],widths = 0.3, patch_artist = True, boxprops=dict(facecolor="green"))
bp2 = plt.boxplot(central_abl[:,ppc_i, :], positions = [0.2, 2.2, 4.2, 6.2, 8.2, 10.2], widths = 0.3, patch_artist = True, boxprops=dict(facecolor="purple"))
plt.grid(True)
plt.xticks([0, 2, 4, 6, 8, 10], [1, 1.1, 1.2, 1.3, 1.4, 1.5])
plt.xlabel("noise level")
plt.ylabel("ARI score")
plt.title("updated method vs. central, 200 ppc, beta = 0.1")
plt.legend([bp1['boxes'][0], bp2['boxes'][0]], ['federated', "central"])

# %%
ppc_i = 2
noise_i = 0
beta_i = 1
bp1 = plt.boxplot(V2_abl[-1,:,beta_i, ppc_i, :], positions = [-0.2,1.8,3.8,5.8,7.8, 9.8],widths = 0.3, patch_artist = True, boxprops=dict(facecolor="green"))
bp2 = plt.boxplot(central_abl[:,ppc_i, :], positions = [0.2, 2.2, 4.2, 6.2, 8.2, 10.2], widths = 0.3, patch_artist = True, boxprops=dict(facecolor="purple"))
plt.grid(True)
plt.xticks([0, 2, 4, 6, 8, 10], [1, 1.1, 1.2, 1.3, 1.4, 1.5])
plt.xlabel("noise level")
plt.ylabel("ARI score")
plt.title("updated method vs. central, 200 ppc, beta = 1")
plt.legend([bp1['boxes'][0], bp2['boxes'][0]], ['federated', "central"])

# %%
ppc_i = 2
noise_i = 0
beta_i = 2
bp1 = plt.boxplot(V2_abl[-1,:,beta_i, ppc_i, :], positions = [-0.2,1.8,3.8,5.8,7.8, 9.8],widths = 0.3, patch_artist = True, boxprops=dict(facecolor="green"))
bp2 = plt.boxplot(central_abl[:,ppc_i, :], positions = [0.2, 2.2, 4.2, 6.2, 8.2, 10.2], widths = 0.3, patch_artist = True, boxprops=dict(facecolor="purple"))
plt.grid(True)
plt.xticks([0, 2, 4, 6, 8, 10], [1, 1.1, 1.2, 1.3, 1.4, 1.5])
plt.xlabel("noise level")
plt.ylabel("ARI score")
plt.title("updated method vs. central, 200 ppc, beta = 10")
plt.legend([bp1['boxes'][0], bp2['boxes'][0]], ['federated', "central"])

# %% [markdown]
# # Synthetic, different distribution per client

# %%
cent_ci = np.genfromtxt("results/cent_synth_ci.csv", delimiter = ",")
om_ci = np.genfromtxt("results/om_synth_ci.csv", delimiter = ",")
ds_ci = np.genfromtxt("results/ds_synth_ci.csv", delimiter = ",")
om_V2_ci = np.genfromtxt("results/cluster_wise_V2.csv", delimiter = ",")
V2_ci_w = np.genfromtxt("results/cluster_wise_V2_weighted.csv", delimiter = ",")

# %%
plt.boxplot(om_ci, widths = 0.5, positions = [0])
plt.boxplot(om_V2_ci[-1, :], widths = 0.5, positions = [2])
plt.boxplot(V2_ci_w[-1, :], widths = 0.5,positions = [4])
plt.boxplot(ds_ci, widths = 0.5, positions = [6])
plt.boxplot(cent_ci, widths = 0.5,positions = [8])
plt.xticks([0, 2,4,6,8], ["Own Method", "Updated\nmethod", "Updated method,\n weighted initialization", "Dennis et. al.", "central"])
plt.grid(True)
plt.title("ARI comparison on highly variable local cluster amount")
#plt.savefig("ci_results.eps",format = "eps")
# Out:
# Text(0.5, 1.0, 'ARI comparison on highly variable local cluster amount')

# %% [markdown]
# # Synthetic, non-uniform

# %%
cent_sd = np.genfromtxt("results/cent_synth_sd.csv", delimiter = ",")
om_sd_natT = np.genfromtxt("results/om_synth_sd_natT.csv", delimiter = ",")
om_sd_t1 = np.genfromtxt("results/om_synth_sd_t1.csv", delimiter = ",")
ds_sd = np.genfromtxt("results/ds_synth_sd.csv", delimiter = ",")

# %%
plt.boxplot(om_sd_t1[-1,:], positions = [0])
plt.boxplot(om_sd_natT[-1,:], positions = [1])
plt.boxplot(om_V2_sd[-1, :], positions = [2])
plt.boxplot(ds_sd, positions = [3])
plt.boxplot(cent_sd, positions = [4])
plt.xticks([0, 1, 2, 3, 4], ["Own Method,\n t=1", "Own Method,\n t = 5.29", "updated method",  "Dennis et. al.","central"])
plt.grid(True)
plt.title("ARI comparison on non-uniform dataset")
plt.savefig("non_uniform_results.eps",format = "eps")

# %% [markdown]
# # FEMNIST

# %%
cent_fn = np.genfromtxt("results/femnist_cent.csv", delimiter = ",")
om_fn_natT = np.genfromtxt("results/femnist_om_natt.csv", delimiter = ",")
om_fn_tuned = np.genfromtxt("results/femnist_om.csv", delimiter = ",")
ds_fn = np.genfromtxt("results/femnist_ds.csv", delimiter = ",")
fn_V2 = np.genfromtxt("results/femnist_V2.csv", delimiter = ",")
ds_fn_untuned = np.genfromtxt("results/femnist_ds_untuned.csv", delimiter = ",")

# %%
fn_V2[-1,:]
# Out:
# array([0.41623747, 0.43219403, 0.42695289, 0.41103424, 0.42979331,
#        0.4223978 , 0.42346465, 0.41940588, 0.43607825, 0.42314109,
#        0.43764835, 0.40411204, 0.4096904 , 0.42461132, 0.45396686,
#        0.43158612, 0.41332772, 0.40350008, 0.42300166, 0.44134961,
#        0.42572237, 0.42656051, 0.42364845, 0.4134657 , 0.43656511,
#        0.41222039, 0.43526549, 0.42339738, 0.42858908, 0.43319253,
#        0.43733984, 0.42176547, 0.42814379, 0.42635692, 0.41980204,
#        0.43840937, 0.41822178, 0.44516371, 0.4199783 , 0.43411573,
#        0.41345815, 0.41381604, 0.4267576 , 0.42672742, 0.42853333,
#        0.40460349, 0.41117673, 0.44406335, 0.44050767, 0.42008107,
#        0.43067523, 0.41522723, 0.40327376, 0.41441772, 0.40818099,
#        0.4208007 , 0.41946212, 0.40193775, 0.43544314, 0.41384187,
#        0.4207197 , 0.40920415, 0.41789744, 0.42341758, 0.42885849,
#        0.40892706, 0.4122245 , 0.41611765, 0.41703878, 0.41820576,
#        0.39978621, 0.42702748, 0.42402443, 0.42394231, 0.39890023,
#        0.41449241, 0.42133211, 0.4320248 , 0.43437507, 0.41977657,
#        0.42389718, 0.39986791, 0.41554918, 0.44534016, 0.42373189,
#        0.42374682, 0.43185801, 0.42085464, 0.42613771, 0.42156485,
#        0.43023973, 0.42054894, 0.42661135, 0.43797296, 0.43480627,
#        0.42756096, 0.41681294, 0.43226977, 0.41667276, 0.40559022])

# %%
plt.boxplot([om_fn_natT, om_fn_tuned, fn_V2, ds_fn, ds_fn_untuned, cent_fn], positions = [0,2,4,6,8,10])
plt.xticks([0,2,4,6, 8, 10],["our method,\n t=0.25", "our method, \n t = 3", "Updated \n method",  "Dennis \n et. al.", "Dennis \n et. al., untuned", "Central"])
plt.title("silhouette scores on a subset of FEMNIST")
plt.grid(True)
plt.savefig("FEMNIST_silh.eps",format = "eps")

# %% [markdown]
# # Dset visualizations

# %%
colors = ['r', 'b', 'g', 'c', 'm']
for i in range(5):
    data, labels = load_data(i, "super_diag")
    plt.plot(data[:,0], data[:,1],".", color = colors[i])
plt.title("distribution of the non-uniform dataset")
#plt.grid(True)
#plt.savefig("non_uniform_dist.eps",format = "eps")
# Out:
# Text(0.5, 1.0, 'distribution of the non-uniform dataset')

# %%
colors = ['r', 'b', 'g', 'c', 'm']
for i in range(5):
    data, labels = load_data(i, "cluster_wise")
    plt.plot(data[:,0], data[:,1],".", color = colors[i])
plt.title("distribution of the local cluster varying dataset")
plt.savefig("ci_dist.eps",format = "eps")

# %%
colors =  ['r', 'b', 'g', 'c', 'm']
noise = 1
ppc = 100
beta = 1
for i in range(5):
    data, labels = load_data(i, "abl", beta=beta, ppc=ppc, noise=noise)
    plt.plot(data[:,0], data[:,1],".", color = colors[i])
plt.title("ppc = " +  str(ppc) + ", noise = "+ str(noise) + ", beta = "+ str(beta))
#plt.savefig("ci_dist.eps",format = "eps")
# Out:
# Text(0.5, 1.0, 'ppc = 100, noise = 1, beta = 1')

# %%
colors =  ['r', 'b', 'g', 'c', 'm']
noise = 2
ppc = 100
beta = 10
for i in range(5):
    data, labels = load_data(i, "abl", beta=beta, ppc=ppc, noise=noise)
    plt.plot(data[:,0], data[:,1],".", color = colors[i])
plt.title("ppc = " +  str(ppc) + ", noise = "+ str(noise) + ", beta = "+ str(beta))
#plt.savefig("ci_dist.eps",format = "eps")
# Out:
# Text(0.5, 1.0, 'ppc = 100, noise = 2, beta = 10')
